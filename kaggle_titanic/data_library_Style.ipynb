# %%
import pandas as pd
train = pd.read_csv("https://raw.githubusercontent.com/developer-sdk/kaggle-python-beginner/master/datas/kaggle-titanic/train.csv")

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train[['Survived','Pclass']].head(3).style.highlight_max(color='lightgreen')
# Out:
# <style type="text/css">
# #T_c56c8_row0_col1, #T_c56c8_row1_col0, #T_c56c8_row2_col0, #T_c56c8_row2_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_c56c8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c56c8_level0_col0" class="col_heading level0 col0" >Survived</th>
#       <th id="T_c56c8_level0_col1" class="col_heading level0 col1" >Pclass</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c56c8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c56c8_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_c56c8_row0_col1" class="data row0 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_c56c8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c56c8_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_c56c8_row1_col1" class="data row1 col1" >1</td>
#     </tr>
#     <tr>
# ...

# %%
train.head(3).style.highlight_null(null_color='red')
# Out:
# <style type="text/css">
# #T_e8427_row0_col10, #T_e8427_row2_col10 {
#   background-color: red;
# }
# </style>
# <table id="T_e8427">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e8427_level0_col0" class="col_heading level0 col0" >PassengerId</th>
#       <th id="T_e8427_level0_col1" class="col_heading level0 col1" >Survived</th>
#       <th id="T_e8427_level0_col2" class="col_heading level0 col2" >Pclass</th>
#       <th id="T_e8427_level0_col3" class="col_heading level0 col3" >Name</th>
#       <th id="T_e8427_level0_col4" class="col_heading level0 col4" >Sex</th>
#       <th id="T_e8427_level0_col5" class="col_heading level0 col5" >Age</th>
#       <th id="T_e8427_level0_col6" class="col_heading level0 col6" >SibSp</th>
#       <th id="T_e8427_level0_col7" class="col_heading level0 col7" >Parch</th>
#       <th id="T_e8427_level0_col8" class="col_heading level0 col8" >Ticket</th>
# ...

# %%
train.head(3).style.background_gradient(cmap='Blues')
#train.head(3).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_a49a4_row0_col0, #T_a49a4_row0_col1, #T_a49a4_row0_col5, #T_a49a4_row0_col7, #T_a49a4_row0_col9, #T_a49a4_row1_col2, #T_a49a4_row1_col7, #T_a49a4_row2_col6, #T_a49a4_row2_col7 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_a49a4_row0_col2, #T_a49a4_row0_col6, #T_a49a4_row1_col1, #T_a49a4_row1_col5, #T_a49a4_row1_col6, #T_a49a4_row1_col9, #T_a49a4_row2_col0, #T_a49a4_row2_col1, #T_a49a4_row2_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_a49a4_row1_col0 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_a49a4_row2_col5 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_a49a4_row2_col9 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# </style>
# <table id="T_a49a4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a49a4_level0_col0" class="col_heading level0 col0" >PassengerId</th>
# ...

# %%
train.head(3).style.bar(subset=["Fare"], color='red')
# Out:
# <style type="text/css">
# #T_3cb1c_row0_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, red 10.2%, transparent 10.2%);
# }
# #T_3cb1c_row1_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, red 100.0%, transparent 100.0%);
# }
# #T_3cb1c_row2_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, red 11.1%, transparent 11.1%);
# }
# </style>
# <table id="T_3cb1c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3cb1c_level0_col0" class="col_heading level0 col0" >PassengerId</th>
#       <th id="T_3cb1c_level0_col1" class="col_heading level0 col1" >Survived</th>
#       <th id="T_3cb1c_level0_col2" class="col_heading level0 col2" >Pclass</th>
#       <th id="T_3cb1c_level0_col3" class="col_heading level0 col3" >Name</th>
#       <th id="T_3cb1c_level0_col4" class="col_heading level0 col4" >Sex</th>
#       <th id="T_3cb1c_level0_col5" class="col_heading level0 col5" >Age</th>
# ...

# %%
train.head(10).style.bar(subset=["Age"], align='mid', color=['red', 'green'])
# Out:
# <style type="text/css">
# #T_e55b5_row0_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, green 40.7%, transparent 40.7%);
# }
# #T_e55b5_row1_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, green 70.4%, transparent 70.4%);
# }
# #T_e55b5_row2_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, green 48.1%, transparent 48.1%);
# }
# #T_e55b5_row3_col5, #T_e55b5_row4_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, green 64.8%, transparent 64.8%);
# }
# #T_e55b5_row5_col5 {
#   width: 10em;
# }
# #T_e55b5_row6_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, green 100.0%, transparent 100.0%);
# }
# #T_e55b5_row7_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, green 3.7%, transparent 3.7%);
# }
# #T_e55b5_row8_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, green 50.0%, transparent 50.0%);
# }
# #T_e55b5_row9_col5 {
#   width: 10em;
# ...
